# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaustavee/AICTE_MICROSOFT_Internship/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/creditcard.csv')

# %%
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 81294  58872  1.104942 -0.900171  0.271719 -0.528821 -1.064148 -0.533231
# 81295  58872 -0.438214  0.492120  2.440138  0.454998 -0.148495  0.476077
# 81296  58872 -0.473593  1.109975  1.704117 -0.019309  0.076774 -0.585510
# 81297  58873 -2.769864  1.253167  0.752106  0.455407 -1.894425  0.539661
# 81298  58874  1.116529 -0.157694 -0.149952  1.059937  0.256352       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  81299.000000  81299.000000  81299.000000  81299.000000  81299.000000
# mean   37671.743256     -0.259996     -0.038228      0.678460      0.163041
# std    15321.247892      1.887739      1.677855      1.382087      1.367118
# min        0.000000    -56.407510    -72.715728    -33.680984     -5.172595
# 25%    30955.500000     -1.021634     -0.601906      0.185895     -0.726028
# 50%    40336.000000     -0.252322      0.068932      0.764270      0.182495
# 75%    49589.000000      1.153522      0.720881      1.393621      1.043485
# max    58874.000000      1.960497     18.902453      4.226108     16.715537
#
#                  V5            V6            V7            V8            V9  \
# count  81299.000000  81298.000000  81298.000000  81298.000000  81298.000000
# mean      -0.277528      0.095578     -0.114114      0.053131     -0.012674
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81299 entries, 0 to 81298
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    81299 non-null  int64
#  1   V1      81299 non-null  float64
#  2   V2      81299 non-null  float64
#  3   V3      81299 non-null  float64
#  4   V4      81299 non-null  float64
#  5   V5      81299 non-null  float64
#  6   V6      81298 non-null  float64
#  7   V7      81298 non-null  float64
#  8   V8      81298 non-null  float64
#  9   V9      81298 non-null  float64
#  10  V10     81298 non-null  float64
#  11  V11     81298 non-null  float64
#  12  V12     81298 non-null  float64
#  13  V13     81298 non-null  float64
#  14  V14     81298 non-null  float64
#  15  V15     81298 non-null  float64
#  16  V16     81298 non-null  float64
#  17  V17     81298 non-null  float64
#  18  V18     81298 non-null  float64
#  19  V19     81298 non-null  float64
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    81100
# 1.0      198
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.head(50)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0      0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5      2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6      4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7      7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8      7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9      9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10    10  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11    10  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12    10  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score

from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
df = df.dropna(subset=['Class'])
df = df.dropna()

X = df.drop(['Class'], axis=1)
y = df['Class']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_scaled, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=42, stratify=y_res)

# %%
from xgboost import XGBClassifier


xgb_model = XGBClassifier(
    eval_metric='logloss',
    verbosity=0,
    tree_method='hist',
    n_jobs=-1
)

# %%
# 1. Import all necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score, roc_curve
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/creditcard.csv')

df = df.dropna(subset=['Class'])
df = df.dropna()


X = df.drop(columns=['Class'])
y = df['Class']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_scaled, y)

X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.3, random_state=42, stratify=y_res
)


xgb_model = XGBClassifier(
    eval_metric='logloss',
    verbosity=0,
    tree_method='hist',
    n_jobs=-1,
    random_state=42
)
xgb_model.fit(X_train, y_train)


y_pred = xgb_model.predict(X_test)
y_prob = xgb_model.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(" XGBoost Evaluation")
print(f"Accuracy: {accuracy:.4f}")
print(f"ROC-AUC: {roc_auc:.4f}")
print("\nClassification Report:\n", report)
print("Confusion Matrix:\n", conf_matrix)


fpr, tpr, _ = roc_curve(y_test, y_prob)
plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label=f'XGBoost (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("XGBoost ROC Curve")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#  XGBoost Evaluation
# Accuracy: 0.9996
# ROC-AUC: 1.0000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       1.00      1.00      1.00     85294
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
#
# Confusion Matrix:
#  [[85233    62]
#  [    0 85294]]

# %%
def test_fraud_transactions(model, data, scaler=None, threshold=0.5):

    import numpy as np
    import pandas as pd


    fraud_data = data[data['Class'] == 1].copy()
    if fraud_data.empty:
        print(" No fraudulent transactions found.")
        return None


    X_fraud = fraud_data.drop(columns=['Class'])
    feature_names = X_fraud.columns  # Save column names
    y_true = fraud_data['Class'].values

    if scaler:
        X_fraud_scaled = scaler.transform(X_fraud)
        X_fraud_df = pd.DataFrame(X_fraud_scaled, columns=feature_names, index=X_fraud.index)
    else:
        X_fraud_df = X_fraud


    y_prob = model.predict_proba(X_fraud_df)[:, 1]
    y_pred = (y_prob >= threshold).astype(int)

    result_df = X_fraud_df.copy()
    result_df['Predicted_Class'] = y_pred
    result_df['Fraud_Probability'] = y_prob


    print(f" Detected {np.sum(y_pred)} out of {len(y_pred)} known fraudulent transactions.")

    return result_df[['Predicted_Class', 'Fraud_Probability'] + list(feature_names)]

# %%
fraud_results = test_fraud_transactions(xgb_model, df, scaler=scaler)
fraud_results.head()
# Out:
#  Detected 492 out of 492 known fraudulent transactions.
#       Predicted_Class  Fraud_Probability      Time        V1        V2  \
# 541                 1           0.999854 -1.988034 -1.180495  1.182090
# 623                 1           0.998675 -1.986644 -1.553864 -1.912006
# 4920                1           0.997302 -1.902623 -1.175963  1.065368
# 6108                1           0.999997 -1.849472 -2.245363  0.822602
# 6329                1           0.999229 -1.838248  0.630132  1.828699
#
#             V3        V4        V5        V6        V7  ...       V20  \
# 541  -1.061730  2.823647 -0.378330 -1.070764 -2.051091  ...  0.164621
# 623   0.717864  1.616427  0.985192 -0.799255  0.263177  ...  2.727039
# 4920 -0.237259  1.645808 -0.595277 -0.056886  0.454550  ... -0.557801
# 6108 -1.710035  1.892684 -0.817341 -1.280925 -2.826143  ... -0.222600
# 6329 -2.838971  3.342686  2.625768 -1.019123  1.385059  ...  0.011753
#
# ...

# %% [markdown]
# # Class Imbalance Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(x='Class', data=df, palette='viridis')
plt.title("Distribution of Legitimate vs Fraudulent Transactions")
plt.xlabel("Class (0 = Legitimate, 1 = Fraud)")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-14-2502702450.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette='viridis')

# %% [markdown]
# # Transaction Amounts by Class (Boxplot)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Class', y='Amount', data=df, palette='Set2')
plt.title("Transaction Amounts by Class")
plt.yscale('log')
plt.xlabel("Class")
plt.ylabel("Transaction Amount (Log Scale)")
plt.show()
# Out:
# /tmp/ipython-input-15-536205091.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='Amount', data=df, palette='Set2')

# %% [markdown]
# # Correlation Heatmap of Features

# %%
plt.figure(figsize=(12, 10))
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', center=0, linewidths=0.5)
plt.title("Correlation Heatmap of Features")
plt.show()

# %% [markdown]
# # Confusion Matrix (from predictions)

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Legit', 'Fraud'], yticklabels=['Legit', 'Fraud'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# #  Feature Importance from XGBoost

# %%
import numpy as np
importances = xgb_model.feature_importances_
features = df.drop(columns='Class').columns

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 6))
sns.barplot(x=importances[indices][:15], y=features[indices][:15], palette="magma")
plt.title("Top 15 Feature Importances - XGBoost")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.show()
# Out:
# /tmp/ipython-input-18-537128064.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances[indices][:15], y=features[indices][:15], palette="magma")

# %% [markdown]
# # Fraud Probability Distribution

# %%
plt.figure(figsize=(7, 5))
sns.histplot(y_prob, bins=50, kde=True, color='red')
plt.title("Predicted Fraud Probability Distribution")
plt.xlabel("Predicted Probability")
plt.ylabel("Transaction Count")
plt.show()
